# %%
# import python libraries

import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt # visualizing data
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# BLOCK -1 BASIC ANALYSIS
# *In this we do perform some basic analysis on raw data and do some cleaning such as removing the null values, checking the duplicate values
#
# *we do change some columns name to make a clear understanding and extract some meaningfulinsights from raw data
#
# *describe- we do describe some colums as we are interested only in those columns in which we get a clear conclusion and better insights

# %%
# import csv file
df = pd.read_csv('global data.csv')

# %%
#Checking the number of columns and rows 
df.shape
# Out:
# (3649, 20)

# %%
df.head()
# Out:
#         Entity  Year  Access to electricity (% of population)  \
# 0  Afghanistan  2000                                 1.613591
# 1  Afghanistan  2001                                 4.074574
# 2  Afghanistan  2002                                 9.409158
# 3  Afghanistan  2003                                14.738506
# 4  Afghanistan  2004                                20.064968
#
#    Access to clean fuels for cooking  \
# 0                                6.2
# 1                                7.2
# 2                                8.2
# 3                                9.5
# 4                               10.9
#
#    Renewable-electricity-generating-capacity-per-capita  \
# 0                                               9.22
# 1                                               8.86
# 2                                               8.47
# 3                                               8.09
# 4                                               7.75
#
# ...

# %% [markdown]
# lets check for some information from dataset that data types of dataset values ,how many non values are there

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3649 entries, 0 to 3648
# Data columns (total 20 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   Entity                                                            3649 non-null   object
#  1   Year                                                              3649 non-null   int64
#  2   Access to electricity (% of population)                           3639 non-null   float64
#  3   Access to clean fuels for cooking                                 3480 non-null   float64
#  4   Renewable-electricity-generating-capacity-per-capita              2718 non-null   float64
#  5   Financial flows to developing countries (US $)                    1560 non-null   float64
#  6   Renewable energy share in the total final energy consumption (%)  3455 non-null   float64
# ...

# %%
#check for null values
pd.isnull(df).sum()
# Out:
# Entity                                                                 0
# Year                                                                   0
# Access to electricity (% of population)                               10
# Access to clean fuels for cooking                                    169
# Renewable-electricity-generating-capacity-per-capita                 931
# Financial flows to developing countries (US $)                      2089
# Renewable energy share in the total final energy consumption (%)     194
# Electricity from fossil fuels (TWh)                                   21
# Electricity from nuclear (TWh)                                       126
# Electricity from renewables (TWh)                                     21
# Low-carbon electricity (% electricity)                                42
# Primary energy consumption per capita (kWh/person)                     0
# Energy intensity level of primary energy (MJ/$2017 PPP GDP)          207
# ...

# %%
#drop the columns which contians large number of null values
df.drop(['Financial flows to developing countries (US $)','Renewables (% equivalent primary energy)'], axis = 1, inplace = True)

# %%
# checking the columns
df.head()
# Out:
#         Entity  Year  Access to electricity (% of population)  \
# 0  Afghanistan  2000                                 1.613591
# 1  Afghanistan  2001                                 4.074574
# 2  Afghanistan  2002                                 9.409158
# 3  Afghanistan  2003                                14.738506
# 4  Afghanistan  2004                                20.064968
#
#    Access to clean fuels for cooking  \
# 0                                6.2
# 1                                7.2
# 2                                8.2
# 3                                9.5
# 4                               10.9
#
#    Renewable-electricity-generating-capacity-per-capita  \
# 0                                               9.22
# 1                                               8.86
# 2                                               8.47
# 3                                               8.09
# 4                                               7.75
#
# ...

# %%
#drop the null values and checking it too
df.dropna(inplace=True)
pd.isnull(df).sum()
# Out:
# Entity                                                              0
# Year                                                                0
# Access to electricity (% of population)                             0
# Access to clean fuels for cooking                                   0
# Renewable-electricity-generating-capacity-per-capita                0
# Renewable energy share in the total final energy consumption (%)    0
# Electricity from fossil fuels (TWh)                                 0
# Electricity from nuclear (TWh)                                      0
# Electricity from renewables (TWh)                                   0
# Low-carbon electricity (% electricity)                              0
# Primary energy consumption per capita (kWh/person)                  0
# Energy intensity level of primary energy (MJ/$2017 PPP GDP)         0
# gdp_growth                                                          0
# ...

# %%
#renaming the colums
df.rename(columns = {'Renewable energy share in the total final energy consumption (%)':'Renewable energy'},inplace = True)

# %%
df.head()
# Out:
#         Entity  Year  Access to electricity (% of population)  \
# 3  Afghanistan  2003                                14.738506
# 4  Afghanistan  2004                                20.064968
# 5  Afghanistan  2005                                25.390894
# 6  Afghanistan  2006                                30.718690
# 7  Afghanistan  2007                                36.051010
#
#    Access to clean fuels for cooking  \
# 3                               9.50
# 4                              10.90
# 5                              12.20
# 6                              13.85
# 7                              15.30
#
#    Renewable-electricity-generating-capacity-per-capita  Renewable energy  \
# 3                                               8.09                36.66
# 4                                               7.75                44.24
# 5                                               7.51                33.88
# ...

# %% [markdown]
# lets identify some duplicate values

# %%
#to check duplicated rows
df.duplicated()
# Out:
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
#         ...
# 3644    False
# 3645    False
# 3646    False
# 3647    False
# 3648    False
# Length: 2103, dtype: bool

# %%
select_col = [
 'Access to electricity (% of population)',
 'Access to clean fuels for cooking',
 'Renewable energy share in the total final energy consumption (%)',
 'Electricity from fossil fuels (TWh)',
 'Electricity from nuclear (TWh)',
 'Electricity from renewables (TWh)',
 'Low-carbon electricity (% electricity)',
 'Primary energy consumption per capita (kWh/person)',
 'Energy intensity level of primary energy (MJ/$2017 PPP GDP)',
 'Value_co2_emissions_kt_by_country',
 'Renewables (% equivalent primary energy)',
 'Renewable-electricity-generating-capacity-per-capita',
 'Financial flows to developing countries (US $)',
 'gdp_growth',
 'gdp_per_capita']

# %%
df.describe
# Out:
# <bound method NDFrame.describe of            Entity  Year  Access to electricity (% of population)  \
# 3     Afghanistan  2003                                14.738506
# 4     Afghanistan  2004                                20.064968
# 5     Afghanistan  2005                                25.390894
# 6     Afghanistan  2006                                30.718690
# 7     Afghanistan  2007                                36.051010
# ...           ...   ...                                      ...
# 3644     Zimbabwe  2016                                42.561730
# 3645     Zimbabwe  2017                                44.178635
# 3646     Zimbabwe  2018                                45.572647
# 3647     Zimbabwe  2019                                46.781475
# 3648     Zimbabwe  2020                                52.747670
#
#       Access to clean fuels for cooking  \
# 3                                  9.50
# 4                                 10.90
# ...

# %% [markdown]
# As there is rise in problem here that there are large number of columns so we can't observe clearly so we need to perform the analysis on some important columns so that we can reach to a understanding conclusion from dataset

# %%
#describing the interested columns
df[['Access to electricity (% of population)','Renewable energy','Electricity from renewables (TWh)']].describe()
# Out:
#        Access to electricity (% of population)  Renewable energy  \
# count                              2103.000000       2103.000000
# mean                                 68.050773         41.925635
# std                                  32.896164         31.586897
# min                                   1.252269          0.000000
# 25%                                  37.889426         11.255000
# 50%                                  82.050000         39.310000
# 75%                                  98.835532         74.660000
# max                                 100.000000         96.040000
#
#        Electricity from renewables (TWh)
# count                        2103.000000
# mean                           18.629225
# std                           108.948216
# min                             0.000000
# 25%                             0.030000
# 50%                             0.750000
# 75%                             5.360000
# max                          2014.570000

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ###FINDING CORRELATION BETWEEN VALUES

# %%
df.corr()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_6360\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                                                         Year  \
# Year                                                1.000000
# Access to electricity (% of population)             0.165751
# Access to clean fuels for cooking                   0.084535
# Renewable-electricity-generating-capacity-per-c...  0.087019
# Renewable energy                                   -0.072963
# Electricity from fossil fuels (TWh)                 0.050973
# Electricity from nuclear (TWh)                      0.061640
# Electricity from renewables (TWh)                   0.064691
# Low-carbon electricity (% electricity)             -0.012188
# Primary energy consumption per capita (kWh/person)  0.023016
# ...

# %% [markdown]
# HeatMap of correlation between values

# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.heatmap(df.corr())
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_6360\3040510.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %% [markdown]
# Analysis of Sustainable goals of India

# %%
df_India=df[df["Entity"]=="India"]
df_India
# Out:
#      Entity  Year  Access to electricity (% of population)  \
# 1534  India  2000                                58.721474
# 1535  India  2001                                55.800000
# 1536  India  2002                                62.300000
# 1537  India  2003                                64.047485
# 1538  India  2004                                64.400000
# 1539  India  2005                                67.579810
# 1540  India  2006                                67.900000
# 1541  India  2007                                71.119865
# 1542  India  2008                                72.899380
# 1543  India  2009                                75.000000
# 1544  India  2010                                76.300000
# 1545  India  2011                                67.600000
# 1546  India  2012                                79.900000
# 1547  India  2013                                81.999330
# 1548  India  2014                                83.872500
# ...

# %%
df_India.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 1534 to 1553
# Data columns (total 18 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   Entity                                                       20 non-null     object
#  1   Year                                                         20 non-null     int64
#  2   Access to electricity (% of population)                      20 non-null     float64
#  3   Access to clean fuels for cooking                            20 non-null     float64
#  4   Renewable-electricity-generating-capacity-per-capita         20 non-null     float64
#  5   Renewable energy                                             20 non-null     float64
#  6   Electricity from fossil fuels (TWh)                          20 non-null     float64
# ...

# %%
df_India.columns
# Out:
# Index(['Entity', 'Year', 'Access to electricity (% of population)',
#        'Access to clean fuels for cooking',
#        'Renewable-electricity-generating-capacity-per-capita',
#        'Renewable energy', 'Electricity from fossil fuels (TWh)',
#        'Electricity from nuclear (TWh)', 'Electricity from renewables (TWh)',
#        'Low-carbon electricity (% electricity)',
#        'Primary energy consumption per capita (kWh/person)',
#        'Energy intensity level of primary energy (MJ/$2017 PPP GDP)',
#        'gdp_growth', 'gdp_per_capita', 'Density\n(P/Km2)', 'Land Area(Km2)',
#        'Latitude', 'Longitude'],
#       dtype='object')

# %%
#Let's remove some undeed columns for a better analysis

# %%
Removed_Columns=["Access to electricity (% of population)","Access to clean fuels for cooking","Land Area(Km2)","Latitude","Longitude"]
df_India.drop(Removed_Columns,axis=1,inplace=True)
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_6360\2037194230.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_India.drop(Removed_Columns,axis=1,inplace=True)

# %%
df_India
# Out:
#      Entity  Year  Renewable-electricity-generating-capacity-per-capita  \
# 1534  India  2000                                              23.66
# 1535  India  2001                                              24.81
# 1536  India  2002                                              24.54
# 1537  India  2003                                              27.23
# 1538  India  2004                                              29.38
# 1539  India  2005                                              31.68
# 1540  India  2006                                              34.85
# 1541  India  2007                                              36.69
# 1542  India  2008                                              39.30
# 1543  India  2009                                              39.61
# 1544  India  2010                                              42.34
# 1545  India  2011                                              46.43
# 1546  India  2012                                              47.76
# ...

# %% [markdown]
# Cleaning the data of india

# %%
print(df_India.duplicated())#checking if there is a duplicate value or not
df_India=df_India.dropna() #dropping the null values 
df_India=df_India.rename(columns={'Entity':'Country'})
df_India=df_India.set_index("Year")
# Out:
# 1534    False
# 1535    False
# 1536    False
# 1537    False
# 1538    False
# 1539    False
# 1540    False
# 1541    False
# 1542    False
# 1543    False
# 1544    False
# 1545    False
# 1546    False
# 1547    False
# 1548    False
# 1549    False
# 1550    False
# 1551    False
# 1552    False
# 1553    False
# dtype: bool

# %%
#checking that all implementation or changes are successfull or not
df_India.columns
# Out:
# Index(['Country', 'Renewable-electricity-generating-capacity-per-capita',
#        'Renewable energy', 'Electricity from fossil fuels (TWh)',
#        'Electricity from nuclear (TWh)', 'Electricity from renewables (TWh)',
#        'Low-carbon electricity (% electricity)',
#        'Primary energy consumption per capita (kWh/person)',
#        'Energy intensity level of primary energy (MJ/$2017 PPP GDP)',
#        'gdp_growth', 'gdp_per_capita', 'Density\n(P/Km2)'],
#       dtype='object')

# %%
df_India
# Out:
#      Country  Renewable-electricity-generating-capacity-per-capita  \
# Year
# 2000   India                                              23.66
# 2001   India                                              24.81
# 2002   India                                              24.54
# 2003   India                                              27.23
# 2004   India                                              29.38
# 2005   India                                              31.68
# 2006   India                                              34.85
# 2007   India                                              36.69
# 2008   India                                              39.30
# 2009   India                                              39.61
# 2010   India                                              42.34
# 2011   India                                              46.43
# 2012   India                                              47.76
# ...

# %% [markdown]
# Analaysing the data frame

# %%
df_India["Electricity from fossil fuels (TWh)"].describe()
# Out:
# count      20.000000
# mean      812.174500
# std       273.861713
# min       475.350000
# 25%       576.455000
# 50%       750.170000
# 75%      1039.077500
# max      1276.320000
# Name: Electricity from fossil fuels (TWh), dtype: float64

# %% [markdown]
# Hence we don't need all from describe but we used few to make a meaningful insights

# %%
df_India["Electricity from renewables (TWh)"].describe()
# Out:
# count     20.000000
# mean     157.380000
# std       64.913159
# min       72.780000
# 25%      108.767500
# 50%      142.180000
# 75%      202.332500
# max      303.160000
# Name: Electricity from renewables (TWh), dtype: float64

# %%
df_India["Electricity from nuclear (TWh)"].describe()
# Out:
# count    20.00000
# mean     26.64600
# std       9.91724
# min      15.23000
# 25%      17.80500
# 50%      22.17000
# 75%      35.37000
# max      45.16000
# Name: Electricity from nuclear (TWh), dtype: float64

# %%
df_new_gr=df_India[["Electricity from fossil fuels (TWh)","Electricity from nuclear (TWh)","Electricity from renewables (TWh)","gdp_growth"]]

# %%
df_new_gr
# Out:
#       Electricity from fossil fuels (TWh)  Electricity from nuclear (TWh)  \
# Year
# 2000                               475.35                           15.77
# 2001                               491.01                           18.89
# 2002                               517.51                           19.35
# 2003                               545.36                           18.14
# 2004                               567.86                           21.26
# 2005                               579.32                           17.73
# 2006                               599.24                           17.63
# 2007                               636.68                           17.83
# 2008                               674.27                           15.23
# 2009                               728.56                           16.82
# 2010                               771.78                           23.08
# 2011                               828.16                           32.22
# ...

# %%
Corr = df_new_gr.corr()
Corr
# Out:
#                                      Electricity from fossil fuels (TWh)  \
# Electricity from fossil fuels (TWh)                             1.000000
# Electricity from nuclear (TWh)                                  0.940067
# Electricity from renewables (TWh)                               0.967422
# gdp_growth                                                      0.109030
#
#                                      Electricity from nuclear (TWh)  \
# Electricity from fossil fuels (TWh)                        0.940067
# Electricity from nuclear (TWh)                             1.000000
# Electricity from renewables (TWh)                          0.903620
# gdp_growth                                                 0.035688
#
#                                      Electricity from renewables (TWh)  \
# Electricity from fossil fuels (TWh)                           0.967422
# Electricity from nuclear (TWh)                                0.903620
# ...

# %%
sns.set(rc = {'figure.figsize' :(5,4)})
sns.heatmap(Corr,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# UNIVARIATE ANALYSIS

# %%
df_India["Density\\n(P/Km2)"].unique()
# Out:
# array(['464'], dtype=object)

# %% [markdown]
# BLOCK-3
# DATA VISUALLIZATION

# %%
plt.plot(df_India["Electricity from fossil fuels (TWh)"])
plt.plot(df_India["Electricity from nuclear (TWh)"])
plt.plot(df_India["Electricity from renewables (TWh)"])

plt.legend(['Legend'], loc=2)
plt.title("Energy Production in India from 2000 to 2019")
plt.xlabel("Year")
plt.ylabel("Energy(in Twh)")
plt.rcParams['figure.figsize'] = [16,6]

# %%
plt.plot(df_India["Low-carbon electricity (% electricity)"])
plt.legend(['Legend'],loc=2)

# %%
df_India["Electricity from fossil fuels (TWh)"].plot(kind="bar")
df_India["Electricity from nuclear (TWh)"].plot(kind="bar")
df_India["Electricity from renewables (TWh)"].plot(kind="bar")
# Out:
# <Axes: xlabel='Year'>

# %%
sns.pairplot()

# %% [markdown]
# Conclusion
# *There has almost been a increase in electricity from all resources like fossil fuels,electricity and renewables in  india
# *There has been more energy prodution from fossil fuels as compared to electriclity and renewables in india
